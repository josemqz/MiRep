# %%
import numpy as np
#import scipy as sp
#import sympy as sym
from matplotlib import pyplot as plt

# %%
np.eye(n)
np.outer(u,v)
np.zeros_like(A)
A = np.copy(A)#??

# %%
x_i = np.linspace(0,3,100)
y_i = lambda x: np.e**x - x**x

# %%
plt.plot(x_i,y_i(x_i))
plt.figure(figsize=(6,12))
plt.show()
